# %%
#crear una cafeteria

import pandas as pd


contadorF = 0
contadorV = 0
contadorA = 0
total = 0
usuarios = 0
totalVentas = 0
cantidadF = 0
cantidadV = 0
cantidadA = 0 
cantidad = 0
cantidad1 = 0
cantidad2 = 0

print("Bienvenido a leo's coffe shop!!!")
print("*****************Menu********************")
shop={"Cafes":["Cappuccino","Americano","Espresso Doble","Caramel Macchiato"], "Precio":["$5000", "$4000", "$5000", "3000"], "Panaderia":["Pan de Queso", "Croissant Mantequilla Jamón y Queso", "Almojábana Tradicional", "Muffin de Chocolate"], "Precios":["$2000","$4000","$2000","$3800"],
      "Bebidas": ["Jugo de naranja","Jugo de mandarina","Aloe Vera", "Limonada de Coco"], "precios": ["$2000","$1800", "$2000", "$3200"]} 
df = pd.DataFrame.from_dict(shop)
print (df)

print()




cafes = input("Hola usuario, que cafe deseas comprar: ")

if cafes == "Cappuccino":
  contadorF = 5000
elif cafes == "Americano":
  contadorF = 4000
elif cafes == "Espresso Doble":
  contadorF = 5000
elif cafes == "Caramel Macchiato":
  contadorF = 3000

cantidad = int(input(f"Cuantos {cafes} deseas comprar: "))
cantidadF = cantidad * contadorF
cantidadF += cantidadF

masF = input("Deseas comprar mas cafes?")

if masF == "Si" or masF=="si":
    cafes = input("Hola usuario, que cafe deseas comprar: ")

    if  cafes == "Cappuccino":
          contadorF = 5000
    elif cafes == "Americano":
          contadorF = 4000
    elif cafes == "Espresso Doble":
          contadorF = 5000
    elif cafes == "Caramel Macchiato":
          contadorF = 3000

    cantidad = int(input(f"Cuantos {cafes} deseas comprar: "))
    cantidadF = cantidad * contadorF
    cantidadF += cantidadF

    masF = input("Deseas comprar mas cafes?")

else:

      pan = input("Que Pan deseas comprar: ")

      if pan == "Pan de Queso":
        contadorV = 6000
      elif pan == "Croissant Mantequilla Jamón y Queso":
        contadorV += 2500
      elif pan == "Almojábana Tradiciona":
        contadorV = 950
      elif pan == "Muffin de Chocolate":
        contadorV = 2800
        
      cantidad1 = int(input(f"Cuantas {pan}es deseas comprar: "))
      cantidadV = cantidad1 * contadorV
      pan += pan

      masV = input("Deseas comprar mas panes?")

      if masV == "si" or masV == "Si":
        verdura = input("Hola usuario, que pan deseas comprar: ")

        if pan == "Pan de Queso":
            contadorV = 6000
        elif pan == "Croissant Mantequilla Jamón y Queso":
            contadorV += 2500
        elif pan == "Almojábana Tradiciona":
            contadorV = 950
        elif pan == "Muffin de Chocolate":
            contadorV = 2800

            cantidad = int(input(f"Cuantas {pan}es deseas comprar: "))
            cantidadV = cantidad * contadorV
            cantidadV += cantidadV

            masV = input("Deseas comprar mas panes?")   

      else:      

            bebidas = input("Que bebidas deseas comprar: ")

            if bebidas == "Jugo de naranja":
              contadorA = 2000
            elif bebidas == "Jugo de mandarina":
              contadorA += 1800
            elif bebidas == "Aloe Vera":
              contadorA = 2000
            elif bebidas == "Limonada de Coco":
              contadorA = 3200
              
            cantidad = int(input(f"Cuantas {bebidas} deseas comprar: "))
            cantidadA = cantidad * contadorA
            cantidadA += cantidadA

            masA = input("Deseas comprar mas Bebidas?")

            if masA == "Si" or masA=="si":
                bebidas = input("Hola usuario, que bebida deseas comprar: ")

                if bebidas == "Limonaria":
                    contadorA = 2000
                elif bebidas == "Jugo de mandarina":
                    contadorA += 1800
                elif bebidas == "Aloe Vera":
                    contadorA = 2000
                elif bebidas == "Limonada de Coco":
                  contadorA = 3200
              
                  cantidad = int(input(f"Cuantas {bebidas} deseas comprar: "))
                  cantidadA = cantidad * aromatica
                  cantidadA += cantidadA
            else:   

                  total = cantidadF + cantidadV + cantidadA

                  print(" ")

                  print("Bienvenido a tu cajero!!!")
                  print("*****************************Factura****************************************")
                  factura={"cafes":[cafes], "Precio1":[cantidadF], "pan":[pan], "Precio2":[cantidadV], "bebidas":[bebidas], "Precio3":[cantidadA],"Total":[total]}
                  dm = pd.DataFrame.from_dict(factura)
                  print (dm)
                  print("Gracias por tu compra!!!")

                  print()



                  final = input("Tenemos un nuevo usuario?") 
                  usuarios += 1



                  if final == "No" or final == "no": 
                    total = cantidadF + cantidadV + cantidadA

                    print(f"El total de tus ventas fueron: {total}")

                    facturacion={"usuarios":[usuarios], "ganancias":[total]}
                    df = pd.DataFrame.from_dict(facturacion)
                    print (df)

                    print("")

                  else:
                      contadorF = 0
                      contadorV = 0
                      contadorA = 0
                      total = 0
                      usuarios = 0
                      totalVentas = 0
                      cantidadF = 0
                      cantidadV = 0
                      cantidadA = 0 

                      print("Bienvenido a tu Cajero!!!")
                      print("*****************Menu********************")
                      shop={"Frutas":["Aguacate","Banano","Coco","Curuba"], "Precio":["$5000", "$700", "$5000", "2000"], "Verduras":["Ahuyama", "Cebolla Larga", "Cebolla Cabezona", "Pepino"], "Precios":["$6000","$2500","$950","$2800"], "Aromaticas": ["Limonaria","Laurel","Manzanilla", "Oregano"], "precios": ["$2000","$1800", "$2000", "$3200"]} 
                      df = pd.DataFrame.from_dict(shop)
                      print (df)

                      print()




                  cafes = input("Hola usuario, que cafe deseas comprar: ")

                  if cafes == "Cappuccino":
                      contadorF = 5000
                  elif cafes == "Americano":
                      contadorF = 4000
                  elif cafes == "Espresso Doble":
                      contadorF = 5000
                  elif cafes == "Caramel Macchiato":
                      contadorF = 3000

                  cantidad = int(input(f"Cuantos {cafes} deseas comprar: "))
                  cantidadF = cantidad * contadorF
                  cantidadF += cantidadF

                  masF = input("Deseas comprar mas cafes?")

                  if masF == "Si" or masF=="si":
                    cafes = input("Hola usuario, que fruta deseas comprar: ")

                    if cafes == "Cappuccino":
                        contadorF = 5000
                    elif cafes == "Americano":
                        contadorF = 4000
                    elif cafes == "Espresso Doble":
                        contadorF = 5000
                    elif cafes == "Caramel Macchiato":
                        contadorF = 3000

                    cantidad = int(input(f"Cuantos {cafes} deseas comprar: "))
                    cantidadF = cantidad * contadorF
                    cantidadF += cantidadF

                    masF = input("Deseas comprar mas cafes?")

                  else:

                      pan = input("Que Pan deseas comprar: ")

                      if pan == "Pan de Queso":
                        contadorV = 6000
                      elif pan == "Croissant Mantequilla Jamón y Queso":
                        contadorV += 2500
                      elif pan == "Almojábana Tradiciona":
                        contadorV = 950
                      elif pan == "Muffin de Chocolate":
                        contadorV = 2800
                        
                      cantidad = int(input(f"Cuantas {pan}es deseas comprar: "))
                      cantidadV = cantidad * contadorV
                      cantidadV += cantidadV

                      masV = input("Deseas comprar mas panes?")

                      if masV == "si" or masV == "Si":
                        verdura = input("Hola usuario, que pan deseas comprar: ")

                        if pan == "Pan de Queso":
                            contadorV = 6000
                        elif pan == "Croissant Mantequilla Jamón y Queso":
                            contadorV += 2500
                        elif pan == "Almojábana Tradiciona":
                            contadorV = 950
                        elif pan == "Muffin de Chocolate":
                            contadorV = 2800

                            cantidad = int(input(f"Cuantas {pan}es deseas comprar: "))
                            cantidadV = cantidad * contadorV
                            cantidadV += cantidadV

                            masV = input("Deseas comprar mas panes?")   

                      else:      

                            bebidas = input("Que bebidas deseas comprar: ")

                            if bebidas == "Jugo de naranja":
                              contadorA = 2000
                            elif bebidas == "Jugo de mandarina":
                              contadorA += 1800
                            elif bebidas == "Aloe Vera":
                              contadorA = 2000
                            elif bebidas == "Limonada de Coco":
                              contadorA = 3200
                              
                            cantidad = int(input(f"Cuantas {bebidas}s deseas comprar: "))
                            cantidadA = cantidad * contadorA
                            cantidadA += cantidadA

                            masA = input("Deseas comprar mas Bebidas?")

                            if masA == "Si" or masA=="si":
                                bebidas = input("Hola usuario, que bebida deseas comprar: ")

                                if bebidas == "Limonaria":
                                    contadorA = 2000
                                elif bebidas == "Jugo de mandarina":
                                    contadorA += 1800
                                elif bebidas == "Aloe Vera":
                                    contadorA = 2000
                                elif bebidas == "Limonada de Coco":
                                  contadorA = 3200
                              
                                  cantidad = int(input(f"Cuantas {bebidas} deseas comprar: "))
                                  cantidadA = cantidad * contadorA
                                  cantidadA += cantidadA
                            else:   

                                  total = cantidadF + cantidadV + cantidadA

                      print(" ")

                      print("Bienvenido a tu cajero!!!")
                      print("*****************************Factura****************************************")
                      factura={"cafes":[cafes], "valor":[contadorF], "panes":[pan], "precio":[contadorV], "bebidas":[bebidas], "Total":[total]}
                      dm = pd.DataFrame.from_dict(factura)
                      print (dm)
                      print("Gracias por tu compra!!!")

                      print()


                      final = input("Tenemos un nuevo usuario?") 
                      usuarios += 1
# Out:
# Bienvenido a leo's coffe shop!!!
# *****************Menu********************
#                Cafes Precio                            Panaderia Precios  \
# 0         Cappuccino  $5000                         Pan de Queso   $2000
# 1          Americano  $4000  Croissant Mantequilla Jamón y Queso   $4000
# 2     Espresso Doble  $5000               Almojábana Tradicional   $2000
# 3  Caramel Macchiato   3000                  Muffin de Chocolate   $3800
#
#              Bebidas precios
# 0    Jugo de naranja   $2000
# 1  Jugo de mandarina   $1800
# 2          Aloe Vera   $2000
# 3   Limonada de Coco   $3200
#
# Hola usuario, que cafe deseas comprar: Cappuccino
# Cuantos Cappuccino deseas comprar: 2
# Deseas comprar mas cafes?no
# Que Pan deseas comprar: Croissant Mantequilla Jamón y Queso
# Cuantas Croissant Mantequilla Jamón y Quesoes deseas comprar: 2
# Deseas comprar mas panes?no
# Que bebidas deseas comprar: Jugo de naranja
# Cuantas Jugo de naranja deseas comprar: 3
# ...
